# %% [markdown]
# 1. How has honey production yield changed from 1998 to 2021?
# 2. Over time, what are the major production trends across the states?
# 3. Does the data show any trends in terms of the number of honey
# producing colonies and yield per colony before 2006, which was when
# concern over Colony Collapse Disorder spread nationwide?
# 4. Are there any patterns that can be observed between total honey
# production and value of production every year?
# 5. How has the value of production, which in some sense could be tied to
# demand, changed every year?
# 6. Constructs the related plots using Seaborn and Matplot apply
# customization and derive insights from the visualization.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Import pandas, numpy, seaborn packages**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mydata = pd.read_csv("/content/drive/MyDrive/Assignmnt Machine Learning[major]/honeyproduction 1998-2021 (1).csv")

# %% [markdown]
# # **Explore the data for non-null and extreme values Explore the data for non-null and extreme values**

# %%
mydata.head()
# Out:
#         State    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0     Alabama   16000.0           71   1136000.0    159000.0        0.72
# 1     Arizona   55000.0           60   3300000.0   1485000.0        0.64
# 2    Arkansas   53000.0           65   3445000.0   1688000.0        0.59
# 3  California  450000.0           83  37350000.0  12326000.0        0.62
# 4    Colorado   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
mydata.describe().transpose()
# Out:
#              count          mean           std        min        25%  \
# numcol       985.0  6.289239e+04  9.416379e+04    2000.00     9000.0
# yieldpercol  985.0  5.840203e+01  1.929170e+01       3.00       45.0
# totalprod    985.0  4.035132e+06  6.752290e+06   84000.00   469000.0
# stocks       985.0  1.167187e+06  2.088589e+06    8000.00   108000.0
# priceperlb   985.0  1.969594e+00  1.177922e+00       0.49        1.2
# prodvalue    985.0  5.939911e+06  9.806595e+06  162000.00  1037000.0
# year         985.0  2.009291e+03  6.962251e+00    1998.00     2003.0
#
#                    50%         75%          max
# numcol         26000.0    68000.00    530000.00
# yieldpercol       55.0       70.00       136.00
# totalprod    1488000.0  3780000.00  46410000.00
# stocks        360000.0  1217000.00  13800000.00
# priceperlb         1.7        2.36         8.23
# prodvalue    2409000.0  5897000.00  83859000.00
# year            2009.0     2015.00      2021.00

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   State        985 non-null    object
#  1   numcol       985 non-null    float64
#  2   yieldpercol  985 non-null    int64
#  3   totalprod    985 non-null    float64
#  4   stocks       985 non-null    float64
#  5   priceperlb   985 non-null    float64
#  6   prodvalue    985 non-null    float64
#  7   year         985 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 61.7+ KB

# %% [markdown]
# # **How many States are included in the dataset?**

# %%
mydata['State'].nunique()
# Out:
# 44

# %% [markdown]
# # **Which are the States that are included in this dataset?**

# %%
mydata['State'].unique()
# Out:
# array(['Alabama', 'Arizona', 'Arkansas', 'California', 'Colorado',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'South Dakota', 'Tennessee', 'Texas', 'Utah',
#        'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin',
#        'Wyoming', 'South Carolina'], dtype=object)

# %% [markdown]
# # **Calculate the average production for each state across all years.**

# %%
mydata[['State', 'totalprod']].groupby('State').mean().round()
# Out:
#                  totalprod
# State
# Alabama           636750.0
# Arizona          1660333.0
# Arkansas         2282833.0
# California      19049792.0
# Colorado         1579333.0
# Florida         14320708.0
# Georgia          3351792.0
# Hawaii           1080417.0
# Idaho            3966958.0
# Illinois          477375.0
# Indiana           448833.0
# Iowa             2010625.0
# Kansas            596042.0
# Kentucky          223042.0
# Louisiana        3646958.0
# Maine             301458.0
# Maryland          211000.0
# Michigan         4836125.0
# Minnesota        8772083.0
# Mississippi      1544375.0
# Missouri          713625.0
# Montana         11072583.0
# Nebraska         2901000.0
# Nevada            439273.0
# New Jersey        401292.0
# New Mexico        476467.0
# New York         3659042.0
# North Carolina    514708.0
# North Dakota    33208333.0
# Ohio             1027583.0
# Oklahoma          201167.0
# Oregon           2362458.0
# Pennsylvania     1121917.0
# South Carolina    604182.0
# South Dakota    17396500.0
# Tennessee         395208.0
# Texas            7388542.0
# Utah             1090000.0
# Vermont           344583.0
# Virginia          241958.0
# Washington       2852500.0
# West Virginia     284708.0
# Wisconsin        4446500.0
# Wyoming          2520583.0

# %%
pd.DataFrame(mydata.groupby("State")["totalprod"].mean().round())
# Out:
#                  totalprod
# State
# Alabama           636750.0
# Arizona          1660333.0
# Arkansas         2282833.0
# California      19049792.0
# Colorado         1579333.0
# Florida         14320708.0
# Georgia          3351792.0
# Hawaii           1080417.0
# Idaho            3966958.0
# Illinois          477375.0
# Indiana           448833.0
# Iowa             2010625.0
# Kansas            596042.0
# Kentucky          223042.0
# Louisiana        3646958.0
# Maine             301458.0
# Maryland          211000.0
# Michigan         4836125.0
# Minnesota        8772083.0
# Mississippi      1544375.0
# Missouri          713625.0
# Montana         11072583.0
# Nebraska         2901000.0
# Nevada            439273.0
# New Jersey        401292.0
# New Mexico        476467.0
# New York         3659042.0
# North Carolina    514708.0
# North Dakota    33208333.0
# Ohio             1027583.0
# Oklahoma          201167.0
# Oregon           2362458.0
# Pennsylvania     1121917.0
# South Carolina    604182.0
# South Dakota    17396500.0
# Tennessee         395208.0
# Texas            7388542.0
# Utah             1090000.0
# Vermont           344583.0
# Virginia          241958.0
# Washington       2852500.0
# West Virginia     284708.0
# Wisconsin        4446500.0
# Wyoming          2520583.0

# %% [markdown]
# # **How many years data is provided in the dataset? And what is the starting and ending year?**

# %%
mydata['year'].nunique()
# Out:
# 24

# %%
mydata['year'].min()
# Out:
# 1998

# %% [markdown]
# # **Which State has seen highest volume in production, and in which year?**

# %%
mydata['year'].max()
# Out:
# 2021

# %%
mydata[mydata['totalprod']== mydata['totalprod'].max()][["State","year"]]
# Out:
#             State  year
# 532  North Dakota  2010

# %% [markdown]
# # **What is the average yield per colony , for each year?**

# %%
mydata[['year', 'yieldpercol']].groupby('year').mean().round()
# Out:
#       yieldpercol
# year
# 1998         70.0
# 1999         65.0
# 2000         68.0
# 2001         65.0
# 2002         67.0
# 2003         63.0
# 2004         65.0
# 2005         64.0
# 2006         62.0
# 2007         59.0
# 2008         61.0
# 2009         54.0
# 2010         56.0
# 2011         55.0
# 2012         55.0
# 2013         53.0
# 2014         57.0
# 2015         55.0
# 2016         54.0
# 2017         53.0
# 2018         48.0
# 2019         51.0
# 2020         50.0
# 2021         47.0

# %% [markdown]
# # **Is there correlation between any 2 Numeric variables? Test for the same using Visual techniques**

# %%
sns.pairplot(mydata[['numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb', 'prodvalue']])

# %%
cor = mydata[['numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb', 'prodvalue']].corr()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(cor,annot=True, cmap='plasma',vmin=-1,vmax=1)
plt.show()

# %% [markdown]
# # **What is the general Production trend from 1998 to 2021? Describe visually**

# %%
plt.figure(figsize=(25,8))
plt.bar(mydata['year'],mydata['prodvalue'])
plt.title('The general production trend' ,fontsize=25)
plt.xlabel('Year',fontsize=25)
plt.ylabel('prodvalue',fontsize = 25)
# Out:
# Text(0, 0.5, 'prodvalue')

# %% [markdown]
# # **How is the production trend for each State? Describe visually - Hint (Use sns.FacetGrid() & g.map() functions)**

# %%
g = sns.FacetGrid(mydata, col="State", col_wrap=3, height=3)
g = g.map(plt.plot, "year", "totalprod", marker=".")
plt.show()

# %% [markdown]
# # **Is there a linear relationship between the Number of Colonies & Value in Production? Check at an overall level, at state and year levels as well**

# %%
sns.lmplot(x="numcol", y="prodvalue", data=mydata,height=7)
plt.show()

# %%
sns.lmplot(x="numcol", y="prodvalue", data=mydata, hue='State',height=8,aspect=1)
plt.show()

# %%
sns.lmplot(x="numcol", y="prodvalue", data=mydata, hue='year',height=8,aspect=2)
plt.show()

# %% [markdown]
# # **Check the distribution of total prodcution across each year using plot**

# %%
plt.figure(figsize=(25,8))
plt.plot(mydata['year'],mydata['totalprod'])
plt.title('Total production each year' ,fontsize=25)
plt.xlabel('Year',fontsize=25)
plt.ylabel('totalprod',fontsize = 25)
# Out:
# Text(0, 0.5, 'totalprod')

# %% [markdown]
# # ***How has the Value in Production changed over the years? ***

# %%
plt.figure(figsize=(25,8))
plt.bar(mydata['year'],mydata['prodvalue'])
plt.title('The value  in  production change over year' ,fontsize=25)
plt.xlabel('Year',fontsize=25)
plt.ylabel('prodvalue',fontsize = 25)
# Out:
# Text(0, 0.5, 'prodvalue')

# %% [markdown]
# # **What is the linear relationship between Production volume & value over the years?**

# %%
sns.lmplot(x="totalprod", y="prodvalue",hue='year', data=mydata,height=7)
